# %%
import os
import json
import re
from soynlp.tokenizer import LTokenizer

# LTokenizer 초기화 (Soynlp는 미리 학습된 LTokenizer를 제공합니다)
tokenizer = LTokenizer()

def load_stopwords(file_path):
    """
    불용어 리스트를 파일에서 불러오기
    :param file_path: 불용어 파일 경로
    :return: 불용어 리스트
    """
    try:
        with open(file_path, 'r', encoding='utf-8') as f:
            stopwords = f.read().splitlines()
    except FileNotFoundError:
        print(f"Error: {file_path} 파일을 찾을 수 없습니다.")
        stopwords = []
    return stopwords

def preprocess_text(text, stopwords):
    """
    텍스트 전처리 함수
    :param text: 입력 텍스트
    :param stopwords: 불용어 리스트
    :return: 전처리된 텍스트
    """
    # 특수문자 제거
    text = re.sub(r'[^가-힣\s]', '', text)
    
    # 형태소 분석 및 불용어 제거
    tokens = tokenizer.tokenize(text)
    tokens = [word for word in tokens if word not in stopwords]
    
    return ' '.join(tokens)

def process_json_file(file_path, stopwords):
    """
    JSON 파일을 전처리하는 함수
    :param file_path: JSON 파일 경로
    :param stopwords: 불용어 리스트
    """
    try:
        with open(file_path, 'r', encoding='utf-8') as f:
            data = json.load(f)
        
        # data가 리스트임을 가정하고 처리
        if isinstance(data, list):
            for item in data:
                if 'content' in item:
                    item['content'] = preprocess_text(item['content'], stopwords)
                if 'title' in item:
                    item['title'] = preprocess_text(item['title'], stopwords)
        
        with open(file_path, 'w', encoding='utf-8') as f:
            json.dump(data, f, ensure_ascii=False, indent=4)
            print(f"{file_path} 파일이 성공적으로 처리되었습니다.")
    except json.JSONDecodeError:
        print(f"Error: {file_path} 파일을 JSON으로 디코딩할 수 없습니다.")
    except Exception as e:
        print(f"Error: {file_path} 파일을 처리하는 중 오류가 발생했습니다. {e}")

def process_json_files_in_folder(folder_path, stopwords):
    """
    폴더 내의 모든 JSON 파일을 전처리하는 함수
    :param folder_path: 폴더 경로
    :param stopwords: 불용어 리스트
    """
    for root, dirs, files in os.walk(folder_path):
        for file in files:
            if file.endswith(".json"):
                file_path = os.path.join(root, file)
                process_json_file(file_path, stopwords)

# %%
# 불용어 파일 경로
stopwords_file_path = "stopwords.txt"
stopwords = load_stopwords(stopwords_file_path)

# 폴더 경로
folder_path = "../../data/news_tickers"

# JSON 파일 처리 함수 호출
process_json_files_in_folder(folder_path, stopwords)
# Out:
# ../../data/news_tickers
# ../../data/news_tickers
# ../../data/news_tickers
# ../../data/news_tickers/2022/03/20220301.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/03/20220317.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/03/20220321.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/03/20220320.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/03/20220316.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/03/20220331.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/03/20220327.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/03/20220307.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/03/20220311.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/03/20220310.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/03/20220306.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/03/20220326.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/03/20220330.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/03/20220325.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/03/20220309.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/03/20220329.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/03/20220313.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/03/20220305.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/03/20220304.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/03/20220312.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/03/20220328.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/03/20220308.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/03/20220324.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/03/20220315.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/03/20220303.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/03/20220323.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/03/20220319.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/03/20220318.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/03/20220322.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/03/20220302.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/03/20220314.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers
# ../../data/news_tickers/2022/04/20220415.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/04/20220403.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/04/20220423.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/04/20220419.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/04/20220418.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/04/20220422.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/04/20220402.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/04/20220414.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/04/20220425.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/04/20220409.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/04/20220429.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/04/20220413.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/04/20220405.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/04/20220404.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/04/20220412.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/04/20220428.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/04/20220408.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/04/20220424.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/04/20220427.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/04/20220407.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/04/20220411.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/04/20220410.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/04/20220406.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/04/20220426.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/04/20220430.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/04/20220401.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/04/20220417.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/04/20220421.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/04/20220420.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/04/20220416.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers
# ../../data/news_tickers/2022/05/20220507.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/05/20220511.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/05/20220531.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/05/20220527.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/05/20220526.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/05/20220530.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/05/20220510.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/05/20220506.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/05/20220521.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/05/20220501.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/05/20220517.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/05/20220516.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/05/20220520.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/05/20220519.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/05/20220523.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/05/20220515.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/05/20220503.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/05/20220502.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/05/20220514.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/05/20220522.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/05/20220518.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/05/20220513.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/05/20220505.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/05/20220529.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/05/20220509.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/05/20220525.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/05/20220524.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/05/20220508.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/05/20220528.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/05/20220504.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/05/20220512.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers
# ../../data/news_tickers/2022/02/20220213.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/02/20220205.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/02/20220209.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/02/20220225.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/02/20220224.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/02/20220208.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/02/20220228.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/02/20220204.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/02/20220212.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/02/20220219.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/02/20220223.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/02/20220215.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/02/20220203.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/02/20220202.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/02/20220214.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/02/20220222.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/02/20220218.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/02/20220221.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/02/20220201.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/02/20220217.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/02/20220216.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/02/20220220.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/02/20220207.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/02/20220211.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/02/20220227.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/02/20220226.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/02/20220210.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/02/20220206.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers
# ../../data/news_tickers/2022/11/20221117.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/11/20221101.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/11/20221121.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/11/20221120.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/11/20221116.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/11/20221127.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/11/20221111.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/11/20221107.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/11/20221106.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/11/20221110.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/11/20221130.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/11/20221126.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/11/20221125.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/11/20221109.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/11/20221129.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/11/20221105.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/11/20221113.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/11/20221112.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/11/20221104.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/11/20221128.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/11/20221108.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/11/20221124.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/11/20221103.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/11/20221115.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/11/20221123.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/11/20221119.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/11/20221118.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/11/20221122.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/11/20221114.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/11/20221102.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers
# ../../data/news_tickers/2022/10/20221005.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/10/20221013.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/10/20221029.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/10/20221009.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/10/20221025.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/10/20221024.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/10/20221008.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/10/20221028.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/10/20221012.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/10/20221004.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/10/20221019.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/10/20221023.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/10/20221003.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/10/20221015.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/10/20221014.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/10/20221002.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/10/20221022.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/10/20221018.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/10/20221021.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/10/20221017.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/10/20221001.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/10/20221016.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/10/20221020.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/10/20221011.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/10/20221007.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/10/20221027.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/10/20221031.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/10/20221030.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/10/20221026.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/10/20221006.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/10/20221010.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers
# ../../data/news_tickers/2022/07/20220706.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/07/20220710.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/07/20220730.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/07/20220726.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/07/20220727.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/07/20220731.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/07/20220711.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/07/20220707.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/07/20220720.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/07/20220716.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/07/20220717.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/07/20220701.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/07/20220721.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/07/20220722.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/07/20220718.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/07/20220714.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/07/20220702.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/07/20220703.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/07/20220715.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/07/20220719.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/07/20220723.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/07/20220728.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/07/20220712.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/07/20220704.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/07/20220724.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/07/20220708.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/07/20220709.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/07/20220725.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/07/20220705.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/07/20220713.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/07/20220729.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers
# ../../data/news_tickers/2022/09/20220911.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/09/20220907.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/09/20220927.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/09/20220930.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/09/20220926.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/09/20220906.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/09/20220910.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/09/20220921.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/09/20220917.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/09/20220901.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/09/20220916.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/09/20220920.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/09/20220919.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/09/20220923.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/09/20220903.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/09/20220915.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/09/20220914.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/09/20220902.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/09/20220922.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/09/20220918.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/09/20220905.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/09/20220913.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/09/20220929.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/09/20220909.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/09/20220925.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/09/20220924.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/09/20220908.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/09/20220928.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/09/20220912.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/09/20220904.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers
# ../../data/news_tickers/2022/08/20220803.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/08/20220815.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/08/20220823.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/08/20220819.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/08/20220818.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/08/20220822.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/08/20220814.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/08/20220802.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/08/20220825.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/08/20220809.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/08/20220829.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/08/20220805.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/08/20220813.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/08/20220812.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/08/20220804.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/08/20220828.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/08/20220808.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/08/20220824.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/08/20220827.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/08/20220831.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/08/20220811.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/08/20220807.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/08/20220806.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/08/20220810.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/08/20220830.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/08/20220826.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/08/20220817.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/08/20220801.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/08/20220821.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/08/20220820.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/08/20220816.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers
# ../../data/news_tickers/2022/01/20220116.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/01/20220120.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/01/20220121.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/01/20220117.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/01/20220101.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/01/20220130.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/01/20220126.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/01/20220106.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/01/20220110.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/01/20220111.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/01/20220107.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/01/20220127.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/01/20220131.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/01/20220108.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/01/20220124.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/01/20220112.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/01/20220104.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/01/20220128.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/01/20220129.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/01/20220105.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/01/20220113.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/01/20220125.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/01/20220109.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/01/20220114.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/01/20220102.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/01/20220118.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/01/20220122.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/01/20220123.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/01/20220119.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/01/20220103.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/01/20220115.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers
# ../../data/news_tickers/2022/06/20220614.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/06/20220602.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/06/20220618.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/06/20220622.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/06/20220623.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/06/20220619.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/06/20220603.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/06/20220615.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/06/20220608.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/06/20220624.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/06/20220612.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/06/20220604.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/06/20220628.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/06/20220629.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/06/20220605.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/06/20220613.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/06/20220625.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/06/20220609.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/06/20220630.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/06/20220626.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/06/20220606.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/06/20220610.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/06/20220611.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/06/20220607.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/06/20220627.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/06/20220616.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/06/20220620.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/06/20220621.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/06/20220617.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/06/20220601.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers
# ../../data/news_tickers/2022/12/20221228.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/12/20221204.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/12/20221212.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/12/20221224.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/12/20221208.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/12/20221209.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/12/20221225.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/12/20221213.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/12/20221205.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/12/20221229.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/12/20221222.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/12/20221218.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/12/20221202.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/12/20221214.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/12/20221215.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/12/20221203.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/12/20221219.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/12/20221223.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/12/20221220.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/12/20221216.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/12/20221201.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/12/20221217.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/12/20221221.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/12/20221210.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/12/20221206.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/12/20221226.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/12/20221230.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/12/20221231.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/12/20221227.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/12/20221207.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2022/12/20221211.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers
# ../../data/news_tickers
# ../../data/news_tickers/2024/03/20240310.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2024/03/20240306.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2024/03/20240326.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2024/03/20240330.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2024/03/20240331.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2024/03/20240327.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2024/03/20240307.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2024/03/20240311.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2024/03/20240320.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2024/03/20240316.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2024/03/20240301.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2024/03/20240317.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2024/03/20240321.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2024/03/20240318.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2024/03/20240322.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2024/03/20240302.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2024/03/20240314.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2024/03/20240315.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2024/03/20240303.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2024/03/20240323.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2024/03/20240319.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2024/03/20240304.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2024/03/20240312.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2024/03/20240328.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2024/03/20240308.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2024/03/20240324.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2024/03/20240325.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2024/03/20240309.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2024/03/20240329.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2024/03/20240313.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2024/03/20240305.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers
# ../../data/news_tickers/2024/04/20240404.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2024/04/20240412.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2024/04/20240428.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2024/04/20240408.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2024/04/20240424.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2024/04/20240425.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2024/04/20240409.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2024/04/20240429.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2024/04/20240413.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2024/04/20240405.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2024/04/20240418.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2024/04/20240422.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2024/04/20240402.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2024/04/20240414.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2024/04/20240415.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2024/04/20240403.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2024/04/20240423.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2024/04/20240419.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2024/04/20240420.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2024/04/20240416.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2024/04/20240401.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2024/04/20240417.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2024/04/20240421.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2024/04/20240410.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2024/04/20240406.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2024/04/20240426.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2024/04/20240430.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2024/04/20240427.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2024/04/20240407.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2024/04/20240411.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers
# ../../data/news_tickers/2024/05/20240516.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2024/05/20240520.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2024/05/20240521.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2024/05/20240501.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2024/05/20240517.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2024/05/20240526.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2024/05/20240530.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2024/05/20240510.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2024/05/20240506.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2024/05/20240507.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2024/05/20240511.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2024/05/20240531.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2024/05/20240527.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2024/05/20240524.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2024/05/20240508.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2024/05/20240528.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2024/05/20240504.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2024/05/20240512.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2024/05/20240513.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2024/05/20240505.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2024/05/20240529.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2024/05/20240509.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2024/05/20240525.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2024/05/20240502.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2024/05/20240514.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2024/05/20240522.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2024/05/20240518.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2024/05/20240519.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2024/05/20240523.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2024/05/20240515.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2024/05/20240503.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers
# ../../data/news_tickers/2024/02/20240202.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2024/02/20240214.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2024/02/20240222.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2024/02/20240218.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2024/02/20240219.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2024/02/20240223.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2024/02/20240215.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2024/02/20240203.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2024/02/20240224.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2024/02/20240208.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2024/02/20240228.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2024/02/20240204.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2024/02/20240212.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2024/02/20240213.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2024/02/20240205.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2024/02/20240229.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2024/02/20240209.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2024/02/20240225.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2024/02/20240226.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2024/02/20240210.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2024/02/20240206.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2024/02/20240207.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2024/02/20240211.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2024/02/20240227.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2024/02/20240216.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2024/02/20240220.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2024/02/20240221.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2024/02/20240201.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2024/02/20240217.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers
# ../../data/news_tickers/2024/01/20240111.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2024/01/20240107.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2024/01/20240127.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2024/01/20240131.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2024/01/20240130.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2024/01/20240126.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2024/01/20240106.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2024/01/20240110.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2024/01/20240121.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2024/01/20240117.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2024/01/20240101.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2024/01/20240116.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2024/01/20240120.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2024/01/20240123.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2024/01/20240119.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2024/01/20240103.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2024/01/20240115.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2024/01/20240114.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2024/01/20240102.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2024/01/20240118.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2024/01/20240122.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2024/01/20240129.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2024/01/20240105.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2024/01/20240113.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2024/01/20240125.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2024/01/20240109.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2024/01/20240108.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2024/01/20240124.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2024/01/20240112.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2024/01/20240104.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2024/01/20240128.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers
# ../../data/news_tickers/2024/06/20240601.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers
# ../../data/news_tickers
# ../../data/news_tickers/2023/03/20230301.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2023/03/20230317.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2023/03/20230321.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2023/03/20230320.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2023/03/20230316.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2023/03/20230331.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2023/03/20230327.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2023/03/20230307.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2023/03/20230311.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2023/03/20230310.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2023/03/20230306.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2023/03/20230326.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2023/03/20230330.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2023/03/20230325.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2023/03/20230309.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2023/03/20230329.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2023/03/20230313.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2023/03/20230305.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2023/03/20230304.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2023/03/20230312.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2023/03/20230328.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2023/03/20230308.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2023/03/20230324.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2023/03/20230315.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2023/03/20230303.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2023/03/20230323.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2023/03/20230319.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2023/03/20230318.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2023/03/20230322.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2023/03/20230302.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2023/03/20230314.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers
# ../../data/news_tickers/2023/04/20230415.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2023/04/20230403.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2023/04/20230423.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2023/04/20230419.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2023/04/20230418.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2023/04/20230422.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2023/04/20230402.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2023/04/20230414.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2023/04/20230425.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2023/04/20230409.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2023/04/20230429.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2023/04/20230413.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2023/04/20230405.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2023/04/20230404.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2023/04/20230412.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2023/04/20230428.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2023/04/20230408.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2023/04/20230424.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2023/04/20230427.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2023/04/20230407.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2023/04/20230411.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2023/04/20230410.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2023/04/20230406.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2023/04/20230426.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2023/04/20230430.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2023/04/20230401.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2023/04/20230417.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2023/04/20230421.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2023/04/20230420.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2023/04/20230416.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers
# ../../data/news_tickers/2023/05/20230507.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2023/05/20230511.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2023/05/20230531.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2023/05/20230527.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2023/05/20230526.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2023/05/20230530.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2023/05/20230510.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2023/05/20230506.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2023/05/20230521.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2023/05/20230501.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2023/05/20230517.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2023/05/20230516.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2023/05/20230520.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2023/05/20230519.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2023/05/20230523.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2023/05/20230515.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2023/05/20230503.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2023/05/20230502.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2023/05/20230514.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2023/05/20230522.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2023/05/20230518.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2023/05/20230513.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2023/05/20230505.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2023/05/20230529.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2023/05/20230509.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2023/05/20230525.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2023/05/20230524.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2023/05/20230508.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2023/05/20230528.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2023/05/20230504.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2023/05/20230512.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers
# ../../data/news_tickers/2023/02/20230213.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2023/02/20230205.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2023/02/20230209.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2023/02/20230225.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2023/02/20230224.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2023/02/20230208.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2023/02/20230228.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2023/02/20230204.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2023/02/20230212.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2023/02/20230219.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2023/02/20230223.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2023/02/20230215.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2023/02/20230203.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2023/02/20230202.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2023/02/20230214.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2023/02/20230222.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2023/02/20230218.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2023/02/20230221.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2023/02/20230201.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2023/02/20230217.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2023/02/20230216.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2023/02/20230220.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2023/02/20230207.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2023/02/20230211.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2023/02/20230227.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2023/02/20230226.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2023/02/20230210.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2023/02/20230206.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers
# ../../data/news_tickers/2023/11/20231117.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2023/11/20231101.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2023/11/20231121.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2023/11/20231120.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2023/11/20231116.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2023/11/20231127.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2023/11/20231111.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2023/11/20231107.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2023/11/20231106.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2023/11/20231110.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2023/11/20231130.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2023/11/20231126.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2023/11/20231125.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2023/11/20231109.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2023/11/20231129.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2023/11/20231105.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2023/11/20231113.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2023/11/20231112.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2023/11/20231104.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2023/11/20231128.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2023/11/20231108.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2023/11/20231124.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2023/11/20231103.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2023/11/20231115.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2023/11/20231123.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2023/11/20231119.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2023/11/20231118.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2023/11/20231122.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2023/11/20231114.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2023/11/20231102.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers
# ../../data/news_tickers/2023/10/20231005.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2023/10/20231013.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2023/10/20231029.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2023/10/20231009.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2023/10/20231025.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2023/10/20231024.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2023/10/20231008.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2023/10/20231028.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2023/10/20231012.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2023/10/20231004.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2023/10/20231019.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2023/10/20231023.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2023/10/20231003.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2023/10/20231015.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2023/10/20231014.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2023/10/20231002.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2023/10/20231022.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2023/10/20231018.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2023/10/20231021.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2023/10/20231017.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2023/10/20231001.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2023/10/20231016.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2023/10/20231020.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2023/10/20231011.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2023/10/20231007.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2023/10/20231027.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2023/10/20231031.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2023/10/20231030.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2023/10/20231026.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2023/10/20231006.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2023/10/20231010.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers
# ../../data/news_tickers/2023/07/20230706.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2023/07/20230710.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2023/07/20230730.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2023/07/20230726.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2023/07/20230727.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2023/07/20230731.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2023/07/20230711.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2023/07/20230707.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2023/07/20230720.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2023/07/20230716.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2023/07/20230717.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2023/07/20230701.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2023/07/20230721.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2023/07/20230722.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2023/07/20230718.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2023/07/20230714.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2023/07/20230702.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2023/07/20230703.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2023/07/20230715.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2023/07/20230719.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2023/07/20230723.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2023/07/20230728.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2023/07/20230712.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2023/07/20230704.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2023/07/20230724.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2023/07/20230708.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2023/07/20230709.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2023/07/20230725.json 파일이 성공적으로 처리되었습니다.
# ...
# ../../data/news_tickers/2021/11/20211112.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2021/11/20211104.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2021/11/20211128.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2021/11/20211129.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2021/11/20211105.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2021/11/20211113.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2021/11/20211125.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2021/11/20211109.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2021/11/20211114.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2021/11/20211102.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2021/11/20211118.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2021/11/20211122.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2021/11/20211123.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2021/11/20211119.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2021/11/20211103.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2021/11/20211115.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2021/11/20211116.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2021/11/20211120.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2021/11/20211121.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2021/11/20211117.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2021/11/20211101.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2021/11/20211130.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2021/11/20211126.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2021/11/20211106.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2021/11/20211110.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2021/11/20211111.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2021/11/20211107.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2021/11/20211127.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers
# ../../data/news_tickers/2021/10/20211020.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2021/10/20211016.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2021/10/20211017.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2021/10/20211001.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2021/10/20211021.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2021/10/20211006.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2021/10/20211010.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2021/10/20211030.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2021/10/20211026.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2021/10/20211027.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2021/10/20211031.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2021/10/20211011.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2021/10/20211007.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2021/10/20211028.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2021/10/20211012.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2021/10/20211004.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2021/10/20211024.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2021/10/20211008.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2021/10/20211009.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2021/10/20211025.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2021/10/20211005.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2021/10/20211013.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2021/10/20211029.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2021/10/20211022.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2021/10/20211018.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2021/10/20211014.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2021/10/20211002.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2021/10/20211003.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2021/10/20211015.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2021/10/20211019.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2021/10/20211023.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers
# ../../data/news_tickers/2021/07/20210719.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2021/07/20210723.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2021/07/20210703.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2021/07/20210715.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2021/07/20210714.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2021/07/20210702.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2021/07/20210722.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2021/07/20210718.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2021/07/20210705.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2021/07/20210713.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2021/07/20210729.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2021/07/20210709.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2021/07/20210725.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2021/07/20210724.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2021/07/20210708.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2021/07/20210728.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2021/07/20210712.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2021/07/20210704.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2021/07/20210711.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2021/07/20210707.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2021/07/20210727.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2021/07/20210731.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2021/07/20210730.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2021/07/20210726.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2021/07/20210706.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2021/07/20210710.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2021/07/20210721.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2021/07/20210717.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2021/07/20210701.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2021/07/20210716.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2021/07/20210720.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers
# ../../data/news_tickers/2021/09/20210922.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2021/09/20210918.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2021/09/20210914.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2021/09/20210902.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2021/09/20210903.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2021/09/20210915.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2021/09/20210919.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2021/09/20210923.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2021/09/20210928.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2021/09/20210912.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2021/09/20210904.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2021/09/20210924.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2021/09/20210908.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2021/09/20210909.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2021/09/20210925.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2021/09/20210905.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2021/09/20210913.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2021/09/20210929.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2021/09/20210906.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2021/09/20210910.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2021/09/20210930.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2021/09/20210926.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2021/09/20210927.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2021/09/20210911.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2021/09/20210907.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2021/09/20210920.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2021/09/20210916.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2021/09/20210917.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2021/09/20210901.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2021/09/20210921.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers
# ../../data/news_tickers/2021/08/20210830.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2021/08/20210826.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2021/08/20210806.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2021/08/20210810.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2021/08/20210811.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2021/08/20210807.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2021/08/20210827.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2021/08/20210831.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2021/08/20210816.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2021/08/20210820.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2021/08/20210821.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2021/08/20210817.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2021/08/20210801.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2021/08/20210814.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2021/08/20210802.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2021/08/20210818.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2021/08/20210822.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2021/08/20210823.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2021/08/20210819.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2021/08/20210803.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2021/08/20210815.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2021/08/20210808.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2021/08/20210824.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2021/08/20210812.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2021/08/20210804.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2021/08/20210828.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2021/08/20210829.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2021/08/20210805.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2021/08/20210813.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2021/08/20210825.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2021/08/20210809.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers
# ../../data/news_tickers/2021/01/20210125.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2021/01/20210109.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2021/01/20210129.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2021/01/20210105.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2021/01/20210113.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2021/01/20210112.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2021/01/20210104.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2021/01/20210128.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2021/01/20210108.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2021/01/20210124.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2021/01/20210103.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2021/01/20210115.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2021/01/20210123.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2021/01/20210119.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2021/01/20210118.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2021/01/20210122.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2021/01/20210114.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2021/01/20210102.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2021/01/20210117.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2021/01/20210101.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2021/01/20210121.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2021/01/20210120.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2021/01/20210116.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2021/01/20210127.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2021/01/20210131.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2021/01/20210111.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2021/01/20210107.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2021/01/20210106.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2021/01/20210110.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2021/01/20210130.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2021/01/20210126.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers
# ../../data/news_tickers/2021/06/20210627.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2021/06/20210611.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2021/06/20210607.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2021/06/20210606.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2021/06/20210610.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2021/06/20210630.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2021/06/20210626.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2021/06/20210617.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2021/06/20210601.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2021/06/20210621.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2021/06/20210620.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2021/06/20210616.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2021/06/20210603.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2021/06/20210615.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2021/06/20210623.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2021/06/20210619.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2021/06/20210618.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2021/06/20210622.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2021/06/20210614.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2021/06/20210602.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2021/06/20210625.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2021/06/20210609.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2021/06/20210629.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2021/06/20210605.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2021/06/20210613.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2021/06/20210612.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2021/06/20210604.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2021/06/20210628.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2021/06/20210608.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2021/06/20210624.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers
# ../../data/news_tickers/2021/12/20211221.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2021/12/20211201.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2021/12/20211217.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2021/12/20211216.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2021/12/20211220.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2021/12/20211207.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2021/12/20211211.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2021/12/20211231.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2021/12/20211227.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2021/12/20211226.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2021/12/20211230.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2021/12/20211210.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2021/12/20211206.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2021/12/20211213.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2021/12/20211205.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2021/12/20211229.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2021/12/20211209.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2021/12/20211225.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2021/12/20211224.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2021/12/20211208.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2021/12/20211228.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2021/12/20211204.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2021/12/20211212.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2021/12/20211219.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2021/12/20211223.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2021/12/20211215.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2021/12/20211203.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2021/12/20211202.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2021/12/20211214.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2021/12/20211222.json 파일이 성공적으로 처리되었습니다.
# ../../data/news_tickers/2021/12/20211218.json 파일이 성공적으로 처리되었습니다.
